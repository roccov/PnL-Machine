# %%
import pandas as pd

# %%
monthly_cz = pd.read_csv(r"C:\Etudes\EPFL\1ère\MA2\ML\PROJECT\data_raw\Predictors\Chen-Zimmerman data fed monthly.csv")

# %%
monthly_cz
# Out:
#             date  AbnormalAccruals  Accruals  AccrualsBM  Activism1  \
# 0     1926-01-30               NaN       NaN         NaN        NaN
# 1     1926-02-27               NaN       NaN         NaN        NaN
# 2     1926-03-31               NaN       NaN         NaN        NaN
# 3     1926-04-30               NaN       NaN         NaN        NaN
# 4     1926-05-28               NaN       NaN         NaN        NaN
# ...          ...               ...       ...         ...        ...
# 1135  2020-08-31         -3.145117 -1.604437    2.048601        NaN
# 1136  2020-09-30         -2.207840  0.461254   -5.130091        NaN
# 1137  2020-10-30         -1.291792  1.730673    3.487634        NaN
# 1138  2020-11-30          5.001525 -0.354817   19.200947        NaN
# 1139  2020-12-31         -0.667450  0.903760   -2.871377        NaN
#
#       Activism2      AdExp    AgeIPO        AM  AnalystRevision  ...  \
# 0           NaN        NaN       NaN       NaN              NaN  ...
# ...
